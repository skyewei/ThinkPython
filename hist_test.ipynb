# %%
import random
import matplotlib.pyplot as plt
import numpy as np

a = []
for i in range(20):
    a.append(random.randint(1,100))

plt.hist(a, 10, normed=True)
# x = np.linspace(1,10,10000)
# a_mean = np.mean(a)
# a_std = np.std(a, ddof=1)
# plt.plot(x, 1/(np.sqrt(2*np.pi)*a_std)*np.exp(-((x-a_mean)**2)/2), linewidth=4)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
 
 
random_state = np.random.RandomState(19680801)
X = random_state.randn(10000)
 
fig, ax = plt.subplots()
ax.hist(X, bins=50, normed=True, color = 'red')
x = np.linspace(-5, 5, 1000)
ax.plot(x, 1 / np.sqrt(2*np.pi) * np.exp(-(x**2)/2), linewidth=2)
plt.show()
