# %%
print('hello, python, I just come back.')
# Out:
# hello, python, I just come back.

# %%
print('6*7 = ', 6 * 7)
print('3**2+3 = ', 3 ** 2 + 3)
print('48/2 = ', 48 / 2)
print('48//2 = ', 48 // 2)
print(' 3^2 = ', 3 ^ 2)         ## 占位运算符
# Out:
# 6*7 =  42
# 3**2+3 =  12
# 48/2 =  24.0
# 48//2 =  24
#  3^2 =  1

# %%
print(type(2))
print(type(2.0))
print(type('h'))
print(type('hello, world.'))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'str'>

# %%
## EOL -- 行结束
print('hello, i just try to make a mistake.)
# Out:
#   File "<ipython-input-12-531b33c03af4>", line 2
#     print('hello, i just try to make a mistake.)
#                                                 ^
# SyntaxError: EOL while scanning string literal

# %%
## EOF -- 文件结束符
print('hello, i just try to make a mistake.'
# Out:
#   File "<ipython-input-2-3bd876a5e185>", line 1
#     print('hello, i just try to make a mistake.'
#                                                 ^
# SyntaxError: unexpected EOF while parsing

# %%
## 同号为正，异号为负；奇数-为负号
print(-2, --2, ---2)
print(+2, ++2, +++2)
print(+-2, -+2)
print(2--2)
print(2++2)
print(2+-2)
# Out:
# -2 2 -2
# 2 2 2
# -2 -2
# 4
# 4
# 0

# %%
## 非法的前导0
print(02)
# Out:
#   File "<ipython-input-22-a2290ff1150a>", line 1
#     print(02)
#            ^
# SyntaxError: invalid token

# %%
## 值类型错误
756'hello'
# Out:
#   File "<ipython-input-26-e10930f599a3>", line 2
#     756'hello'
#              ^
# SyntaxError: invalid syntax

# %%
print('42分42秒一共是', 42*60+42)
# Out:
# 42分42秒一共是 2562

# %%
print('10公里换算为 %.2f 英里.' %(10/1.61))
# Out:
# 10公里换算为 6.21 英里.

# %%
print('42分42秒跑完了10公里，则每英里耗时 %.2f min, 耗时 %.2f s.' % (43/(10/1.61), (42*60+42)/(10/1.61)) )
print('则每小时跑了 %.2f 英里.' % ( (10/1.61) / ((42*60+42)/3600) ))
# Out:
# 42分42秒跑完了10公里，则每英里耗时 6.92 min, 耗时 412.48 s.
# 则每小时跑了 8.73 英里.
